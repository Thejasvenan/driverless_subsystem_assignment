# %% [markdown]
# <a href="https://colab.research.google.com/github/Thejasvenan/driverless_subsystem_assignment/blob/main/Cone_Detection_Training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install Roboflow and Ultralytics (YOLOv8)
# !pip install -q roboflow ultralytics

# Import the libraries
from roboflow import Roboflow
import os

rf = Roboflow(api_key="QyX34pDDWhot2BTlJzOH")
project = rf.workspace("cone-xrbfs").project("cone-xy8w7")
version = project.version(1)
dataset = version.download("yolov8")
# -----------------------------------------

# Get the path to the data.yaml file created by Roboflow
yaml_path = os.path.join(dataset.location, 'data.yaml')
print(f"Dataset downloaded and config file is at: {yaml_path}")

print("\n--- Starting the training process ---")
# Start training for 40 epochs.
# !yolo task=detect mode=train model=yolov8n.pt data={yaml_path} epochs=40 imgsz=640
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 7.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 20.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 48.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 50.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 108.0 MB/s eta 0:00:00
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to cone-1 in yolov8:: 100%|██████████| 440/440 [00:00<00:00, 6563.16it/s]
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
